# %%
import re
import pandas as pd
import phonenumbers
from email_validator import validate_email, EmailNotValidError
import validators
import recordlinkage
from recordlinkage.preprocessing import phonetic, clean

# %%
# Local Env: nameparser is an external Python library not included in Snowflake Snowplow standard conda packages
from nameparser import HumanName

# %%
# dbt Env
# Import wheel loader and nameparser library from stage: OTHER_PYTHON_PACKAGES
import wheel_loader
wheel_loader.load('nameparser-1.1.3-py2.py3-none-any.whl')
from nameparser import HumanName

# %%
# Local Env
# Create session (for dbt, this is passed into the model)
import json
import snowflake.connector
from snowflake.snowpark import Session

# Get secrets from file
secrets_file = open('secrets.json', 'r')
secrets = json.load(secrets_file)

# Connection parameters
snowflake_account = secrets.get('snowflake_account')
snowflake_user = secrets.get('snowflake_user')
snowflake_password = secrets.get('snowflake_password')
snowflake_role = secrets.get('snowflake_role')
snowflake_database = secrets.get('snowflake_database')
snowflake_warehouse = secrets.get('snowflake_warehouse')

schema_name = secrets.get('snowflake_schema')
connection_parameters = {
    "account": snowflake_account,
    "user": snowflake_user,
    "password": snowflake_password,
    "role": snowflake_role,
    "warehouse": snowflake_warehouse,
    "database": snowflake_database,
    "schema": schema_name
}
# Create a Snowflake Snowpark Session
session =  Session.builder.configs(connection_parameters).create()

# Create dbt object
class dbtObj:
    def __init__(self, config) -> None:
        self.config = config

dbt = dbtObj(
    config={
        # Variables passed from yaml file go here
        # 'pii_schema': 'COFFEE_SHOP',
    }
)

# %%
# Local Env: Get data from model int_contacts__union_all
contacts_query = """
        select *
        from {}.{}.int_contacts__union_all
""".format(snowflake_database, schema_name)

# Query database
contacts = session.sql(contacts_query).collect()
  
# Reset index
contacts_df = pd.DataFrame(contacts)
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ...  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...
# 3               martin-morris.at  2023-01-01  2023-12-18  ...
# 4                      white.org  2023-01-01  2023-09-25  ...
# ...                          ...         ...         ...  ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...
#
#       FILE_LAST_MODIFIED  FAVORITE_COLOR COMPANY_REVENUE COMPANY_EMPLOYEES  \
# 0    2024-01-18 15:07:37            gray             NaN               NaN
# 1    2024-01-18 15:07:37           olive             NaN               NaN
# 2    2024-01-18 15:07:37            lime             NaN               NaN
# 3    2024-01-18 15:07:37           black             NaN               NaN
# 4    2024-01-18 15:07:37            navy             NaN               NaN
# ...                  ...             ...             ...               ...
# 2557 2024-01-18 14:48:35            None     576768431.0            4506.0
# 2558 2024-01-18 14:48:35            None     167947486.0           13578.0
# 2559 2024-01-18 14:48:35            None     992687764.0            2169.0
# 2560 2024-01-18 14:48:35            None     935436658.0            8717.0
# 2561 2024-01-18 14:48:35            None     851099384.0            7236.0
#
#      COMPANY_INDUSTRY  INTENT_SIGNALS  DO_NOT_CALL IP_ADDRESS COUNTRY_NAME  \
# 0                None            None         None       None         None
# 1                None            None         None       None         None
# 2                None            None         None       None         None
# 3                None            None         None       None         None
# 4                None            None         None       None         None
# ...               ...             ...          ...        ...          ...
# 2557             Tech            None         None       None        Chile
# 2558          Finance            None         None       None      Germany
# 2559       Healthcare            None         None       None        Spain
# 2560        Logistics            None         None       None        Japan
# 2561       Healthcare            None         None       None      Germany
#
#      COUNTRY_CODE
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 2557           CL
# 2558           DE
# 2559           ES
# 2560           JP
# 2561           DE
#
# [2562 rows x 23 columns]

# %%
# dbt Env: Get data from model int_contacts__union_all
contacts_df = dbt.ref("int_contacts__union_all")

# %%
# Check Email: Uses Python library email-validator for validating and normalizing email addresses
# Reference: https://github.com/JoshData/python-email-validator
def check_email(email):
    if email is None:
        return None, None
    try:
        validator = validate_email(email, check_deliverability=False)
        email_info = validator.normalized
        is_valid = True
    except (EmailNotValidError, TypeError) as e:
        email_info = None
        is_valid = False
        print(f"INVALID email: {email}, ERROR: {e}")
    return is_valid, email_info

# %%
check_email("bogus@@")[0]
# Out:
# INVALID email: bogus@@, ERROR: The email address is not valid. It must have exactly one @-sign.
# False

# %%
# Check Email: Add is_email_valid and email_info (normalized email or error message)
contacts_df['is_email_valid'] =  contacts_df['EMAIL_ADDRESS'].apply(check_email).str[0]
contacts_df['email_address_clean'] =  contacts_df['EMAIL_ADDRESS'].apply(check_email).str[1]
# Out:
# INVALID email: ms..dds@morales-fowler-jones.biz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: dr..md@richardson-ltd.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dudley@bailey-thomas.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: darryl.jr.@martinez-brown-manning.com, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mr..dds@howard-inc.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..obrien@dunn-lopez-jackson.ai, ERROR: An email address cannot have two periods in a row.
# INVALID email: mjr.@case-ltd.org, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mrs..bennett@kelly-moses-pitts.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..hardin@king-kim.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..md@martinez-morris-garcia.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..md@martinez-morris-garcia.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: dr..md@richardson-ltd.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dudley@bailey-thomas.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..hardin@king-kim.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..obrien@dunn-lopez-jackson.ai, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@howard-inc.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..bennett@kelly-moses-pitts.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..richardson@hurst-sons.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mjr.@case-ltd.org, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: ms..dds@morales-fowler-jones.biz, ERROR: An email address cannot have two periods in a row.
# INVALID email: darryl.jr.@martinez-brown-manning.com, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..richardson@hurst-sons.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.
# INVALID email: ms..dds@morales-fowler-jones.biz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: dr..md@richardson-ltd.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dudley@bailey-thomas.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: darryl.jr.@martinez-brown-manning.com, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mr..dds@howard-inc.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..obrien@dunn-lopez-jackson.ai, ERROR: An email address cannot have two periods in a row.
# INVALID email: mjr.@case-ltd.org, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mrs..bennett@kelly-moses-pitts.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..hardin@king-kim.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..md@martinez-morris-garcia.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..md@martinez-morris-garcia.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: dr..md@richardson-ltd.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dudley@bailey-thomas.at, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..hardin@king-kim.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..obrien@dunn-lopez-jackson.ai, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@howard-inc.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mrs..bennett@kelly-moses-pitts.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..richardson@hurst-sons.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mjr.@case-ltd.org, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: ms..dds@morales-fowler-jones.biz, ERROR: An email address cannot have two periods in a row.
# INVALID email: darryl.jr.@martinez-brown-manning.com, ERROR: An email address cannot have a period immediately before the @-sign.
# INVALID email: mr..dds@reyes-ltd.xyz, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..richardson@hurst-sons.com, ERROR: An email address cannot have two periods in a row.
# INVALID email: mr..bowman@barton-vega.io, ERROR: An email address cannot have two periods in a row.

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ... COMPANY_REVENUE  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...             NaN
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...             NaN
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...             NaN
# 3               martin-morris.at  2023-01-01  2023-12-18  ...             NaN
# 4                      white.org  2023-01-01  2023-09-25  ...             NaN
# ...                          ...         ...         ...  ...             ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...     576768431.0
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...     167947486.0
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...     992687764.0
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...     935436658.0
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...     851099384.0
#
#       COMPANY_EMPLOYEES COMPANY_INDUSTRY INTENT_SIGNALS DO_NOT_CALL  \
# 0                   NaN             None           None        None
# 1                   NaN             None           None        None
# 2                   NaN             None           None        None
# 3                   NaN             None           None        None
# 4                   NaN             None           None        None
# ...                 ...              ...            ...         ...
# 2557             4506.0             Tech           None        None
# 2558            13578.0          Finance           None        None
# 2559             2169.0       Healthcare           None        None
# 2560             8717.0        Logistics           None        None
# 2561             7236.0       Healthcare           None        None
#
#       IP_ADDRESS  COUNTRY_NAME COUNTRY_CODE is_email_valid  \
# 0           None          None         None           True
# 1           None          None         None           True
# 2           None          None         None           True
# 3           None          None         None           True
# 4           None          None         None           True
# ...          ...           ...          ...            ...
# 2557        None         Chile           CL           True
# 2558        None       Germany           DE           True
# 2559        None         Spain           ES           True
# 2560        None         Japan           JP           True
# 2561        None       Germany           DE           True
#
#                         email_address_clean
# 0      michael.walker@ryan-soto-thompson.io
# 1        dkennedy@calderon-allen-graham.org
# 2     casey.miller@johnston-harris-brown.io
# 3                    rhall@martin-morris.at
# 4                          tsmith@white.org
# ...                                     ...
# 2557       satkinson@shaffer-baker-walsh.at
# 2558      pbennett@brady-johnson-nelson.xyz
# 2559  todd.adams@price-rodriguez-little.biz
# 2560       swallace@murray-riley-shields.at
# 2561            anna.cross@carpenter-inc.at
#
# [2562 rows x 25 columns]

# %%
# Check IP Address: Uses Python library validators for validating the IP Address
# Reference: https://validators.readthedocs.io/en/latest/#basic-validators
def check_ip_address(ip_address):
    if ip_address == '' or ip_address is None:
        return None
    is_valid = validators.ipv6(ip_address)
    if is_valid:
        # print('Valid ipv6')
        return True
    # print('Not ipv6')
    is_valid = validators.ipv4(ip_address)
    if is_valid:
        # print('Valid ipv4')
        return True
    # print('Not ipv4')
    print(f"INVALID ip_address: {ip_address}")
    return False

# %%
check_ip_address("255.255.255.1")
# Out:
# True

# %%
# Check IP Address: Add is_ip_addr_valid
contacts_df['is_ip_addr_valid'] =  contacts_df['IP_ADDRESS'].apply(check_ip_address)

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ...  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...
# 3               martin-morris.at  2023-01-01  2023-12-18  ...
# 4                      white.org  2023-01-01  2023-09-25  ...
# ...                          ...         ...         ...  ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...
#
#      COMPANY_EMPLOYEES  COMPANY_INDUSTRY INTENT_SIGNALS DO_NOT_CALL  \
# 0                  NaN              None           None        None
# 1                  NaN              None           None        None
# 2                  NaN              None           None        None
# 3                  NaN              None           None        None
# 4                  NaN              None           None        None
# ...                ...               ...            ...         ...
# 2557            4506.0              Tech           None        None
# 2558           13578.0           Finance           None        None
# 2559            2169.0        Healthcare           None        None
# 2560            8717.0         Logistics           None        None
# 2561            7236.0        Healthcare           None        None
#
#      IP_ADDRESS  COUNTRY_NAME  COUNTRY_CODE is_email_valid  \
# 0          None          None          None           True
# 1          None          None          None           True
# 2          None          None          None           True
# 3          None          None          None           True
# 4          None          None          None           True
# ...         ...           ...           ...            ...
# 2557       None         Chile            CL           True
# 2558       None       Germany            DE           True
# 2559       None         Spain            ES           True
# 2560       None         Japan            JP           True
# 2561       None       Germany            DE           True
#
#                         email_address_clean is_ip_addr_valid
# 0      michael.walker@ryan-soto-thompson.io             None
# 1        dkennedy@calderon-allen-graham.org             None
# 2     casey.miller@johnston-harris-brown.io             None
# 3                    rhall@martin-morris.at             None
# 4                          tsmith@white.org             None
# ...                                     ...              ...
# 2557       satkinson@shaffer-baker-walsh.at             None
# 2558      pbennett@brady-johnson-nelson.xyz             None
# 2559  todd.adams@price-rodriguez-little.biz             None
# 2560       swallace@murray-riley-shields.at             None
# 2561            anna.cross@carpenter-inc.at             None
#
# [2562 rows x 26 columns]

# %%
# Check Domain: Uses Python library validators for validating the Company Domain
# Reference: https://validators.readthedocs.io/en/latest/#basic-validators
def check_domain(company_domain):
    if company_domain == "" or company_domain is None:
        return None
    is_valid = validators.domain(company_domain)
    if is_valid:
        # print('Valid domain')
        return True    
    print(f"INVALID company_domain: {company_domain}")
    return False

# %%
check_domain("google.com")
# Out:
# True

# %%
# Check Company Domain: Add is_company_domain_valid
contacts_df['is_company_domain_valid'] =  contacts_df['COMPANY_DOMAIN'].apply(check_domain)

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ...  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...
# 3               martin-morris.at  2023-01-01  2023-12-18  ...
# 4                      white.org  2023-01-01  2023-09-25  ...
# ...                          ...         ...         ...  ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...
#
#      COMPANY_INDUSTRY  INTENT_SIGNALS DO_NOT_CALL IP_ADDRESS COUNTRY_NAME  \
# 0                None            None        None       None         None
# 1                None            None        None       None         None
# 2                None            None        None       None         None
# 3                None            None        None       None         None
# 4                None            None        None       None         None
# ...               ...             ...         ...        ...          ...
# 2557             Tech            None        None       None        Chile
# 2558          Finance            None        None       None      Germany
# 2559       Healthcare            None        None       None        Spain
# 2560        Logistics            None        None       None        Japan
# 2561       Healthcare            None        None       None      Germany
#
#       COUNTRY_CODE  is_email_valid                    email_address_clean  \
# 0             None            True   michael.walker@ryan-soto-thompson.io
# 1             None            True     dkennedy@calderon-allen-graham.org
# 2             None            True  casey.miller@johnston-harris-brown.io
# 3             None            True                 rhall@martin-morris.at
# 4             None            True                       tsmith@white.org
# ...            ...             ...                                    ...
# 2557            CL            True       satkinson@shaffer-baker-walsh.at
# 2558            DE            True      pbennett@brady-johnson-nelson.xyz
# 2559            ES            True  todd.adams@price-rodriguez-little.biz
# 2560            JP            True       swallace@murray-riley-shields.at
# 2561            DE            True            anna.cross@carpenter-inc.at
#
#      is_ip_addr_valid is_company_domain_valid
# 0                None                    True
# 1                None                    True
# 2                None                    True
# 3                None                    True
# 4                None                    True
# ...               ...                     ...
# 2557             None                    True
# 2558             None                    True
# 2559             None                    True
# 2560             None                    True
# 2561             None                    True
#
# [2562 rows x 27 columns]

# %%
# Clean Phone Number: Validate and re-format phone number to E164 w/ extension
# Reference: https://github.com/daviddrysdale/python-phonenumbers
def clean_phone_number(phone, country_code='US'):
    if phone == "" or phone is None:
        return None, None
    # Replace leading 001- with +1-
    if phone[0:4] == '001-':# Clean Phone Numbers: Uses Python library phonenumbers for validating and formatting phone numbers
        phone_number = f"+1-{phone[4:]}"
    else:
        phone_number = phone
    try:
        phone_obj = phonenumbers.parse(phone_number, country_code)
        extension = phone_obj.extension
        formattted_phone_number = phonenumbers.format_number(phone_obj, phonenumbers.PhoneNumberFormat.E164)
        if extension:
            phone_str = f'{formattted_phone_number}x{extension}'
        else:
            phone_str = formattted_phone_number
        return True, phone_str
    except Exception as e:
        print(f"INVALID phone_number: {phone}, ERROR: {e}")
        return False, str(e)

# %%
phone_number = '+-3399999999-3333'
clean_phone_number(phone_number, 'US')
# Out:
# (True, '+33999999993333')

# %%
# Clean Phone Number: Validate and re-format phone number to E164 w/ extension
# This checks/cleans phone numbers based on 'US' country_code default, b/c only 1 source has country_code populated
# Also, all phone numbers in the datasets seem to follow the US/Canada phone format.
contacts_df['is_phone_us_valid'] =  contacts_df['PHONE_NUMBER'].apply(clean_phone_number).str[0]
contacts_df['phone_number_clean'] =  contacts_df['PHONE_NUMBER'].apply(clean_phone_number).str[1]

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ... DO_NOT_CALL  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...        None
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...        None
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...        None
# 3               martin-morris.at  2023-01-01  2023-12-18  ...        None
# 4                      white.org  2023-01-01  2023-09-25  ...        None
# ...                          ...         ...         ...  ...         ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...        None
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...        None
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...        None
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...        None
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...        None
#
#       IP_ADDRESS COUNTRY_NAME COUNTRY_CODE is_email_valid  \
# 0           None         None         None           True
# 1           None         None         None           True
# 2           None         None         None           True
# 3           None         None         None           True
# 4           None         None         None           True
# ...          ...          ...          ...            ...
# 2557        None        Chile           CL           True
# 2558        None      Germany           DE           True
# 2559        None        Spain           ES           True
# 2560        None        Japan           JP           True
# 2561        None      Germany           DE           True
#
#                         email_address_clean  is_ip_addr_valid  \
# 0      michael.walker@ryan-soto-thompson.io              None
# 1        dkennedy@calderon-allen-graham.org              None
# 2     casey.miller@johnston-harris-brown.io              None
# 3                    rhall@martin-morris.at              None
# 4                          tsmith@white.org              None
# ...                                     ...               ...
# 2557       satkinson@shaffer-baker-walsh.at              None
# 2558      pbennett@brady-johnson-nelson.xyz              None
# 2559  todd.adams@price-rodriguez-little.biz              None
# 2560       swallace@murray-riley-shields.at              None
# 2561            anna.cross@carpenter-inc.at              None
#
#      is_company_domain_valid is_phone_us_valid  phone_number_clean
# 0                       True              True        +13667398129
# 1                       True              True   +18912366451x6535
# 2                       True              True        +12826654872
# 3                       True              True        +17703066694
# 4                       True              True        +17178143111
# ...                      ...               ...                 ...
# 2557                    True              True        +14108266507
# 2558                    True              True        +13133482696
# 2559                    True              True        +14543511516
# 2560                    True              True    +13757603115x286
# 2561                    True              True  +12204199430x58015
#
# [2562 rows x 29 columns]

# %%
# Parse Name: Returns first_name, last_name from a full_name that may contain initials, prefixes, suffixes.
# A better option would be to use an external library: nameparser
#   but this library is not available (in standard conda libraries) in Snowflake Snowpark
def parse_name(full_name):
    if full_name == "" or full_name is None:
        return None, None
    first_name = ''
    last_name = ''
    # Remove name prefix and suffix
    prefix = re.search('^((Mr|Mrs|Ms|Miss|Dr|Prof)(\.|\s)+)?', full_name).group()
    suffix = re.search('(\,|\.|\s){0,3}((Sr|Jr|I|II|III|IV|V|JD|MD|PhD)(\.|\s)*){0,3}$', full_name).group()
    if len(suffix) == 0:
        clean_full_name = full_name[len(prefix):].strip().title()
    else:
        clean_full_name = full_name[len(prefix):-len(suffix)].strip().title()
    name_parts = re.findall(r'\s|\,|\.|[^,\s]+', clean_full_name)
    # Deal with full_name: Last, First {M. I.}
    if ',' in name_parts:
        if len(name_parts) >= 2:
            last_name = name_parts[0].strip().title()
            get_index = name_parts.index(',') + 1
            for x in range(get_index, len(name_parts)):
                if len(name_parts[x].strip()) >= 1:
                    first_name = name_parts[x].strip().title()
        elif len(name_parts) == 1:
            first_name = ''
            last_name = name_parts[0].strip().title()
        else:
            first_name = ''
            last_name = ''
    # Deal with full_name: Fist {M. I.} Last
    else:
        if len(name_parts) >= 2:
            first_name = name_parts[0].strip().title()
            last_name = name_parts[-1].strip().title()
        elif len(name_parts) == 1:
            first_name = ''
            last_name = name_parts[-1].strip().title()
        else:
            first_name = ''
            last_name = ''
    # print(f"first_name: {first_name}, last_name: {last_name}")
    return first_name, last_name

# %%
parse_name('Prof. Jeffrey S. Huth, Jr. II PhD')
# Out:
# ('Jeffrey', 'Huth')

# %%
parse_name('Mr. Huth, Jeffrey')
# Out:
# ('Jeffrey', 'Huth')

# %%
# Parse name into first and last name for matching using nameparser library.
#   nameparser is an external Python library not included in Snowflake Snowplow standard conda packages
# Reference: https://github.com/derek73/python-nameparser
def parse_name_2(full_name):
    if full_name == '' or full_name is None:
        return '', ''
    first_name = ''
    last_name = ''
    try:
        name_obj = HumanName(full_name)
        last_name = name_obj.last
        first_name = name_obj.first
    except Exception as e:
        print(f"Error: {e}")
    return first_name, last_name

# %%
parse_name_2("Dr. Jeffrey S. Huth, Jr. PhD")
# Out:
# ('Jeffrey', 'Huth')

# %%
parse_name_2("Dr. Juan Q. Xavier de la Vega III (Doc Vega)")
# Out:
# ('Juan', 'de la Vega')

# %%
# Add first_name and last_name to the dataset
contacts_df['first_name'] =  contacts_df['NAME'].apply(parse_name_2).str[0]
contacts_df['last_name'] =  contacts_df['NAME'].apply(parse_name_2).str[1]

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ... COUNTRY_NAME  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...         None
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...         None
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...         None
# 3               martin-morris.at  2023-01-01  2023-12-18  ...         None
# 4                      white.org  2023-01-01  2023-09-25  ...         None
# ...                          ...         ...         ...  ...          ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...        Chile
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...      Germany
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...        Spain
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...        Japan
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...      Germany
#
#       COUNTRY_CODE is_email_valid                    email_address_clean  \
# 0             None           True   michael.walker@ryan-soto-thompson.io
# 1             None           True     dkennedy@calderon-allen-graham.org
# 2             None           True  casey.miller@johnston-harris-brown.io
# 3             None           True                 rhall@martin-morris.at
# 4             None           True                       tsmith@white.org
# ...            ...            ...                                    ...
# 2557            CL           True       satkinson@shaffer-baker-walsh.at
# 2558            DE           True      pbennett@brady-johnson-nelson.xyz
# 2559            ES           True  todd.adams@price-rodriguez-little.biz
# 2560            JP           True       swallace@murray-riley-shields.at
# 2561            DE           True            anna.cross@carpenter-inc.at
#
#      is_ip_addr_valid  is_company_domain_valid  is_phone_us_valid  \
# 0                None                     True               True
# 1                None                     True               True
# 2                None                     True               True
# 3                None                     True               True
# 4                None                     True               True
# ...               ...                      ...                ...
# 2557             None                     True               True
# 2558             None                     True               True
# 2559             None                     True               True
# 2560             None                     True               True
# 2561             None                     True               True
#
#       phone_number_clean first_name last_name
# 0           +13667398129    Michael    Walker
# 1      +18912366451x6535    Douglas   Kennedy
# 2           +12826654872      Casey    Miller
# 3           +17703066694     Ronald      Hall
# 4           +17178143111       Troy     Smith
# ...                  ...        ...       ...
# 2557        +14108266507     Steven  Atkinson
# 2558        +13133482696      Peter   Bennett
# 2559        +14543511516       Todd     Adams
# 2560    +13757603115x286       Sean   Wallace
# 2561  +12204199430x58015       Anna     Cross
#
# [2562 rows x 31 columns]

# %%
# Pre-process names to clean and get phonetic versions
# Clean the first, last, company names and add phonetic versions metaphone, match_rating, and nysiis
contacts_df['first_name_clean'] =  clean(contacts_df['first_name'])
contacts_df['last_name_clean'] =  clean(contacts_df['last_name'])
contacts_df['company_name_clean'] =  clean(contacts_df['COMPANY_NAME'])

# Metaphone Approach, Reference: https://en.wikipedia.org/wiki/Metaphone
contacts_df['first_name_mp'] =  phonetic(contacts_df['first_name_clean'], 'match_rating')
contacts_df['last_name_mp'] =  phonetic(contacts_df['last_name_clean'], 'match_rating')
contacts_df['company_name_mp'] =  phonetic(contacts_df['company_name_clean'], 'match_rating')

# Match Rating Approach, Reference: https://en.wikipedia.org/wiki/Match_rating_approach
contacts_df['first_name_mra'] =  phonetic(contacts_df['first_name_clean'], 'match_rating')
contacts_df['last_name_mra'] =  phonetic(contacts_df['last_name_clean'], 'match_rating')
contacts_df['company_name_mra'] =  phonetic(contacts_df['company_name_clean'], 'match_rating')

# NYSIIS Approach, Reference: https://en.wikipedia.org/wiki/New_York_State_Identification_and_Intelligence_System
contacts_df['first_name_nysiis'] =  phonetic(contacts_df['first_name_clean'], 'nysiis')
contacts_df['last_name_nysiis'] =  phonetic(contacts_df['last_name_clean'], 'nysiis')
contacts_df['company_name_nysiis'] =  phonetic(contacts_df['company_name_clean'], 'nysiis')

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ...  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...
# 3               martin-morris.at  2023-01-01  2023-12-18  ...
# 4                      white.org  2023-01-01  2023-09-25  ...
# ...                          ...         ...         ...  ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...
#
#               company_name_clean  first_name_mp last_name_mp company_name_mp  \
# 0         ryan soto and thompson           MCHL         WLKR          RYNPSN
# 1      calderon allen and graham           DGLS         KNDY          CLDRHM
# 2      johnston harris and brown            CSY          MLR          JHNRWN
# 3                  martin morris           RNLD           HL          MRTMRS
# 4                      white llc            TRY         SMTH           WHTLC
# ...                          ...            ...          ...             ...
# 2557     shaffer baker and walsh           STVN       ATKNSN          SHFLSH
# 2558    brady johnson and nelson            PTR          BNT          BRDLSN
# 2559  price rodriguez and little             TD         ADMS          PRCLTL
# 2560    murray riley and shields             SN          WLC          MRYLDS
# 2561               carpenter inc             AN          CRS          CRPRNC
#
#      first_name_mra  last_name_mra  company_name_mra first_name_nysiis  \
# 0              MCHL           WLKR            RYNPSN             MACAL
# 1              DGLS           KNDY            CLDRHM              DAGL
# 2               CSY            MLR            JHNRWN              CASY
# 3              RNLD             HL            MRTMRS            RANALD
# 4               TRY           SMTH             WHTLC               TRY
# ...             ...            ...               ...               ...
# 2557           STVN         ATKNSN            SHFLSH            STAFAN
# 2558            PTR            BNT            BRDLSN             PATAR
# 2559             TD           ADMS            PRCLTL               TAD
# 2560             SN            WLC            MRYLDS               SAN
# 2561             AN            CRS            CRPRNC                AN
#
#      last_name_nysiis    company_name_nysiis
# 0              WALCAR      RYANSATANDTANPSAN
# 1              CANADY  CALDARANALANANDGRAHAN
# 2               MALAR    JANSTANARASANDBRAON
# 3                 HAL               MARTANAR
# 4                SNAT                 WATALC
# ...               ...                    ...
# 2557         ATCANSAN       SAFARBACARANDWAL
# 2558            BANAT   BRADYJANSANANDNALSAN
# 2559             ADAN   PRACARADRAGASANDLATL
# 2560            WALAC      MARAYRALAYANDSALD
# 2561               CR           CARPANTARANC
#
# [2562 rows x 43 columns]

# %%
# Get First Initial: Substring first letter of first name
def get_first_initial(first_name):
    if first_name == '' or first_name is None:
        return None
    return first_name[0]

# %%
get_first_initial('Jeff')
# Out:
# 'J'

# %%
# Get First Initial: Add a column for first_initial
contacts_df['first_initial'] =  contacts_df['first_name'].apply(get_first_initial)

# %%
display(contacts_df)
# Out:
#                     SOURCE_CONTACT_KEY SOURCE_NAME             NAME  \
# 0     62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 1     2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 2     10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 3     1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 4     351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                ...         ...              ...
# 2557  4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 2558  51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# 2559  d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 2560  672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 2561  3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                               EMAIL_ADDRESS           PHONE_NUMBER  \
# 0      michael.walker@ryan-soto-thompson.io           366-739-8129
# 1        dkennedy@calderon-allen-graham.org  001-891-236-6451x6535
# 2     casey.miller@johnston-harris-brown.io       001-282-665-4872
# 3                    rhall@martin-morris.at          (770)306-6694
# 4                          tsmith@white.org        +1-717-814-3111
# ...                                     ...                    ...
# 2557       satkinson@shaffer-baker-walsh.at           410.826.6507
# 2558      pbennett@brady-johnson-nelson.xyz             3133482696
# 2559  todd.adams@price-rodriguez-little.biz           454-351-1516
# 2560       swallace@murray-riley-shields.at   001-375-760-3115x286
# 2561            anna.cross@carpenter-inc.at     220-419-9430x58015
#
#                               TITLE                 COMPANY_NAME  \
# 0                                IC      Ryan, Soto and Thompson
# 1                                IC   Calderon, Allen and Graham
# 2                                IC   Johnston, Harris and Brown
# 3     CEO (Chief Executive Officer)                Martin-Morris
# 4                                IC                    White LLC
# ...                             ...                          ...
# 2557                             IC     Shaffer, Baker and Walsh
# 2558                             IC    Brady, Johnson and Nelson
# 2559                             IC  Price, Rodriguez and Little
# 2560                      Team Lead    Murray, Riley and Shields
# 2561                             IC                Carpenter Inc
#
#                   COMPANY_DOMAIN  CREATED_AT  UPDATED_AT  ... first_name_mp  \
# 0          ryan-soto-thompson.io  2023-01-01  2023-03-02  ...          MCHL
# 1      calderon-allen-graham.org  2023-01-01  2023-11-27  ...          DGLS
# 2       johnston-harris-brown.io  2023-01-01  2023-10-26  ...           CSY
# 3               martin-morris.at  2023-01-01  2023-12-18  ...          RNLD
# 4                      white.org  2023-01-01  2023-09-25  ...           TRY
# ...                          ...         ...         ...  ...           ...
# 2557      shaffer-baker-walsh.at  2023-12-22  2023-12-22  ...          STVN
# 2558    brady-johnson-nelson.xyz  2023-12-25  2023-12-25  ...           PTR
# 2559  price-rodriguez-little.biz  2023-12-28  2023-12-28  ...            TD
# 2560     murray-riley-shields.at  2023-12-29  2023-12-29  ...            SN
# 2561            carpenter-inc.at  2023-12-31  2023-12-31  ...            AN
#
#       last_name_mp company_name_mp first_name_mra last_name_mra  \
# 0             WLKR          RYNPSN           MCHL          WLKR
# 1             KNDY          CLDRHM           DGLS          KNDY
# 2              MLR          JHNRWN            CSY           MLR
# 3               HL          MRTMRS           RNLD            HL
# 4             SMTH           WHTLC            TRY          SMTH
# ...            ...             ...            ...           ...
# 2557        ATKNSN          SHFLSH           STVN        ATKNSN
# 2558           BNT          BRDLSN            PTR           BNT
# 2559          ADMS          PRCLTL             TD          ADMS
# 2560           WLC          MRYLDS             SN           WLC
# 2561           CRS          CRPRNC             AN           CRS
#
#       company_name_mra  first_name_nysiis last_name_nysiis  \
# 0               RYNPSN              MACAL           WALCAR
# 1               CLDRHM               DAGL           CANADY
# 2               JHNRWN               CASY            MALAR
# 3               MRTMRS             RANALD              HAL
# 4                WHTLC                TRY             SNAT
# ...                ...                ...              ...
# 2557            SHFLSH             STAFAN         ATCANSAN
# 2558            BRDLSN              PATAR            BANAT
# 2559            PRCLTL                TAD             ADAN
# 2560            MRYLDS                SAN            WALAC
# 2561            CRPRNC                 AN               CR
#
#         company_name_nysiis first_initial
# 0         RYANSATANDTANPSAN             M
# 1     CALDARANALANANDGRAHAN             D
# 2       JANSTANARASANDBRAON             C
# 3                  MARTANAR             R
# 4                    WATALC             T
# ...                     ...           ...
# 2557       SAFARBACARANDWAL             S
# 2558   BRADYJANSANANDNALSAN             P
# 2559   PRACARADRAGASANDLATL             T
# 2560      MARAYRALAYANDSALD             S
# 2561           CARPANTARANC             A
#
# [2562 rows x 44 columns]

# %%
# Set unique index on contacts_df
contacts_df = contacts_df.set_index('SOURCE_CONTACT_KEY')

# %%
# Sort the dataframme
contacts_df.sort_values('last_name').head()
display(contacts_df)
# Out:
#                                  SOURCE_NAME             NAME  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f         crm   Michael Walker
# 2e0ab3bebb2cb59f274c7a8d3242f30a         crm  Douglas Kennedy
# 10bccf1772b0871e8ffc3b6fe71e028a         crm     Casey Miller
# 1b4b88791adea115155b95c3087450e6         crm      Ronald Hall
# 351cbda9179109c81f7913343916bfcb         crm       Troy Smith
# ...                                      ...              ...
# 4a301b7835136852512017c195e5d57a        acme  Steven Atkinson
# 51b6c194ee7f54a06022016581b73671        acme    Peter Bennett
# d121ed3c7f55c56ac8d0fa13a6eba6ee        acme       Todd Adams
# 672f1bae98aecbbd17469698283b976c        acme     Sean Wallace
# 3972d538bf202fb438a0ac95e054367d        acme       Anna Cross
#
#                                                           EMAIL_ADDRESS  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f   michael.walker@ryan-soto-thompson.io
# 2e0ab3bebb2cb59f274c7a8d3242f30a     dkennedy@calderon-allen-graham.org
# 10bccf1772b0871e8ffc3b6fe71e028a  casey.miller@johnston-harris-brown.io
# 1b4b88791adea115155b95c3087450e6                 rhall@martin-morris.at
# 351cbda9179109c81f7913343916bfcb                       tsmith@white.org
# ...                                                                 ...
# 4a301b7835136852512017c195e5d57a       satkinson@shaffer-baker-walsh.at
# 51b6c194ee7f54a06022016581b73671      pbennett@brady-johnson-nelson.xyz
# d121ed3c7f55c56ac8d0fa13a6eba6ee  todd.adams@price-rodriguez-little.biz
# 672f1bae98aecbbd17469698283b976c       swallace@murray-riley-shields.at
# 3972d538bf202fb438a0ac95e054367d            anna.cross@carpenter-inc.at
#
#                                            PHONE_NUMBER  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f           366-739-8129
# 2e0ab3bebb2cb59f274c7a8d3242f30a  001-891-236-6451x6535
# 10bccf1772b0871e8ffc3b6fe71e028a       001-282-665-4872
# 1b4b88791adea115155b95c3087450e6          (770)306-6694
# 351cbda9179109c81f7913343916bfcb        +1-717-814-3111
# ...                                                 ...
# 4a301b7835136852512017c195e5d57a           410.826.6507
# 51b6c194ee7f54a06022016581b73671             3133482696
# d121ed3c7f55c56ac8d0fa13a6eba6ee           454-351-1516
# 672f1bae98aecbbd17469698283b976c   001-375-760-3115x286
# 3972d538bf202fb438a0ac95e054367d     220-419-9430x58015
#
#                                                           TITLE  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f                             IC
# 2e0ab3bebb2cb59f274c7a8d3242f30a                             IC
# 10bccf1772b0871e8ffc3b6fe71e028a                             IC
# 1b4b88791adea115155b95c3087450e6  CEO (Chief Executive Officer)
# 351cbda9179109c81f7913343916bfcb                             IC
# ...                                                         ...
# 4a301b7835136852512017c195e5d57a                             IC
# 51b6c194ee7f54a06022016581b73671                             IC
# d121ed3c7f55c56ac8d0fa13a6eba6ee                             IC
# 672f1bae98aecbbd17469698283b976c                      Team Lead
# 3972d538bf202fb438a0ac95e054367d                             IC
#
#                                                  COMPANY_NAME  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f      Ryan, Soto and Thompson
# 2e0ab3bebb2cb59f274c7a8d3242f30a   Calderon, Allen and Graham
# 10bccf1772b0871e8ffc3b6fe71e028a   Johnston, Harris and Brown
# 1b4b88791adea115155b95c3087450e6                Martin-Morris
# 351cbda9179109c81f7913343916bfcb                    White LLC
# ...                                                       ...
# 4a301b7835136852512017c195e5d57a     Shaffer, Baker and Walsh
# 51b6c194ee7f54a06022016581b73671    Brady, Johnson and Nelson
# d121ed3c7f55c56ac8d0fa13a6eba6ee  Price, Rodriguez and Little
# 672f1bae98aecbbd17469698283b976c    Murray, Riley and Shields
# 3972d538bf202fb438a0ac95e054367d                Carpenter Inc
#
#                                               COMPANY_DOMAIN  CREATED_AT  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f       ryan-soto-thompson.io  2023-01-01
# 2e0ab3bebb2cb59f274c7a8d3242f30a   calderon-allen-graham.org  2023-01-01
# 10bccf1772b0871e8ffc3b6fe71e028a    johnston-harris-brown.io  2023-01-01
# 1b4b88791adea115155b95c3087450e6            martin-morris.at  2023-01-01
# 351cbda9179109c81f7913343916bfcb                   white.org  2023-01-01
# ...                                                      ...         ...
# 4a301b7835136852512017c195e5d57a      shaffer-baker-walsh.at  2023-12-22
# 51b6c194ee7f54a06022016581b73671    brady-johnson-nelson.xyz  2023-12-25
# d121ed3c7f55c56ac8d0fa13a6eba6ee  price-rodriguez-little.biz  2023-12-28
# 672f1bae98aecbbd17469698283b976c     murray-riley-shields.at  2023-12-29
# 3972d538bf202fb438a0ac95e054367d            carpenter-inc.at  2023-12-31
#
#                                   UPDATED_AT                      FILE_NM  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f  2023-03-02   contacts/crm__contacts.csv
# 2e0ab3bebb2cb59f274c7a8d3242f30a  2023-11-27   contacts/crm__contacts.csv
# 10bccf1772b0871e8ffc3b6fe71e028a  2023-10-26   contacts/crm__contacts.csv
# 1b4b88791adea115155b95c3087450e6  2023-12-18   contacts/crm__contacts.csv
# 351cbda9179109c81f7913343916bfcb  2023-09-25   contacts/crm__contacts.csv
# ...                                      ...                          ...
# 4a301b7835136852512017c195e5d57a  2023-12-22  contacts/acme__contacts.csv
# 51b6c194ee7f54a06022016581b73671  2023-12-25  contacts/acme__contacts.csv
# d121ed3c7f55c56ac8d0fa13a6eba6ee  2023-12-28  contacts/acme__contacts.csv
# 672f1bae98aecbbd17469698283b976c  2023-12-29  contacts/acme__contacts.csv
# 3972d538bf202fb438a0ac95e054367d  2023-12-31  contacts/acme__contacts.csv
#
#                                   ...  first_name_mp last_name_mp  \
# SOURCE_CONTACT_KEY                ...
# 62afe6edd2e1b38285768d566398716f  ...           MCHL         WLKR
# 2e0ab3bebb2cb59f274c7a8d3242f30a  ...           DGLS         KNDY
# 10bccf1772b0871e8ffc3b6fe71e028a  ...            CSY          MLR
# 1b4b88791adea115155b95c3087450e6  ...           RNLD           HL
# 351cbda9179109c81f7913343916bfcb  ...            TRY         SMTH
# ...                               ...            ...          ...
# 4a301b7835136852512017c195e5d57a  ...           STVN       ATKNSN
# 51b6c194ee7f54a06022016581b73671  ...            PTR          BNT
# d121ed3c7f55c56ac8d0fa13a6eba6ee  ...             TD         ADMS
# 672f1bae98aecbbd17469698283b976c  ...             SN          WLC
# 3972d538bf202fb438a0ac95e054367d  ...             AN          CRS
#
#                                  company_name_mp first_name_mra  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f          RYNPSN           MCHL
# 2e0ab3bebb2cb59f274c7a8d3242f30a          CLDRHM           DGLS
# 10bccf1772b0871e8ffc3b6fe71e028a          JHNRWN            CSY
# 1b4b88791adea115155b95c3087450e6          MRTMRS           RNLD
# 351cbda9179109c81f7913343916bfcb           WHTLC            TRY
# ...                                          ...            ...
# 4a301b7835136852512017c195e5d57a          SHFLSH           STVN
# 51b6c194ee7f54a06022016581b73671          BRDLSN            PTR
# d121ed3c7f55c56ac8d0fa13a6eba6ee          PRCLTL             TD
# 672f1bae98aecbbd17469698283b976c          MRYLDS             SN
# 3972d538bf202fb438a0ac95e054367d          CRPRNC             AN
#
#                                   last_name_mra  company_name_mra  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f           WLKR            RYNPSN
# 2e0ab3bebb2cb59f274c7a8d3242f30a           KNDY            CLDRHM
# 10bccf1772b0871e8ffc3b6fe71e028a            MLR            JHNRWN
# 1b4b88791adea115155b95c3087450e6             HL            MRTMRS
# 351cbda9179109c81f7913343916bfcb           SMTH             WHTLC
# ...                                         ...               ...
# 4a301b7835136852512017c195e5d57a         ATKNSN            SHFLSH
# 51b6c194ee7f54a06022016581b73671            BNT            BRDLSN
# d121ed3c7f55c56ac8d0fa13a6eba6ee           ADMS            PRCLTL
# 672f1bae98aecbbd17469698283b976c            WLC            MRYLDS
# 3972d538bf202fb438a0ac95e054367d            CRS            CRPRNC
#
#                                  first_name_nysiis last_name_nysiis  \
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f             MACAL           WALCAR
# 2e0ab3bebb2cb59f274c7a8d3242f30a              DAGL           CANADY
# 10bccf1772b0871e8ffc3b6fe71e028a              CASY            MALAR
# 1b4b88791adea115155b95c3087450e6            RANALD              HAL
# 351cbda9179109c81f7913343916bfcb               TRY             SNAT
# ...                                            ...              ...
# 4a301b7835136852512017c195e5d57a            STAFAN         ATCANSAN
# 51b6c194ee7f54a06022016581b73671             PATAR            BANAT
# d121ed3c7f55c56ac8d0fa13a6eba6ee               TAD             ADAN
# 672f1bae98aecbbd17469698283b976c               SAN            WALAC
# 3972d538bf202fb438a0ac95e054367d                AN               CR
#
#                                     company_name_nysiis first_initial
# SOURCE_CONTACT_KEY
# 62afe6edd2e1b38285768d566398716f      RYANSATANDTANPSAN             M
# 2e0ab3bebb2cb59f274c7a8d3242f30a  CALDARANALANANDGRAHAN             D
# 10bccf1772b0871e8ffc3b6fe71e028a    JANSTANARASANDBRAON             C
# 1b4b88791adea115155b95c3087450e6               MARTANAR             R
# 351cbda9179109c81f7913343916bfcb                 WATALC             T
# ...                                                 ...           ...
# 4a301b7835136852512017c195e5d57a       SAFARBACARANDWAL             S
# 51b6c194ee7f54a06022016581b73671   BRADYJANSANANDNALSAN             P
# d121ed3c7f55c56ac8d0fa13a6eba6ee   PRACARADRAGASANDLATL             T
# 672f1bae98aecbbd17469698283b976c      MARAYRALAYANDSALD             S
# 3972d538bf202fb438a0ac95e054367d           CARPANTARANC             A
#
# [2562 rows x 43 columns]

# %%
indexer = recordlinkage.Index()
indexer.full()
candidate_record_pairs = indexer.index(contacts_df)
print("Number of candidate record pairs", len(candidate_record_pairs))
#candidate_record_pairs.to_frame(index=False)
#(5000*5000-5000)/2 = 12 497 500


# This is WAY TOO MANY!
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.
# Number of candidate record pairs 3280641

# %%
# Match and de-duplicate with the recordlinkage Python library
# Reference: https://recordlinkage.readthedocs.io/en/latest/guides/data_deduplication.html

# Initialize indexer: Only compare records with the same last_name_clean
indexer_1 = recordlinkage.Index()
indexer_1.block(left_on="last_name_clean")
candidate_links_1 = indexer_1.index(contacts_df)

# Initialize indexer: Only compare records with the same phone_number_clean
indexer_2 = recordlinkage.Index()
indexer_2.block(left_on="phone_number_clean")
candidate_links_2 = indexer_2.index(contacts_df)

# Every record against every record
indexer_3 = recordlinkage.Index()
indexer_3.full()
candidate_links_3 = indexer_3.index(contacts_df)
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
# Comparison types for fields in all source files
compare_cl = recordlinkage.Compare()
compare_cl.exact("last_name_mp", "last_name_mp", label="last_name_mp")
compare_cl.exact("first_name_mp", "first_name_mp", label="first_name_mp")
compare_cl.exact("first_initial", "first_initial", label="first_initial")
compare_cl.exact("email_address_clean", "email_address_clean", label="email_address_clean")
compare_cl.exact("phone_number_clean", "phone_number_clean", label="phone_number_clean")
compare_cl.exact("TITLE", "TITLE", label="title")
compare_cl.string("company_name_clean", "company_name_clean", method="jarowinkler", threshold=0.7, label="company_name_clean")

features_1 = compare_cl.compute(candidate_links_1, contacts_df)
features_2 = compare_cl.compute(candidate_links_2, contacts_df)
features_3 = compare_cl.compute(candidate_links_3, contacts_df)

# %%
features_3.describe()
# Out:
#        last_name_mp  first_name_mp  first_initial  email_address_clean  \
# count  3.280641e+06   3.280641e+06   3.280641e+06         3.280641e+06
# mean   4.900872e-03   7.013264e-03   7.685480e-02         5.047794e-04
# std    6.983448e-02   8.345106e-02   2.663610e-01         2.246163e-02
# min    0.000000e+00   0.000000e+00   0.000000e+00         0.000000e+00
# 25%    0.000000e+00   0.000000e+00   0.000000e+00         0.000000e+00
# 50%    0.000000e+00   0.000000e+00   0.000000e+00         0.000000e+00
# 75%    0.000000e+00   0.000000e+00   0.000000e+00         0.000000e+00
# max    1.000000e+00   1.000000e+00   1.000000e+00         1.000000e+00
#
#        phone_number_clean         title  company_name_clean
# count        3.280641e+06  3.280641e+06        3.280641e+06
# mean         6.449959e-04  5.245234e-01        1.822784e-02
# std          2.538858e-02  4.993983e-01        1.337744e-01
# min          0.000000e+00  0.000000e+00        0.000000e+00
# 25%          0.000000e+00  0.000000e+00        0.000000e+00
# 50%          0.000000e+00  1.000000e+00        0.000000e+00
# 75%          0.000000e+00  1.000000e+00        0.000000e+00
# max          1.000000e+00  1.000000e+00        1.000000e+00

# %%
# Matches based on the number of matching features
features_3.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 7.0       1345
# 6.0        326
# 5.0        609
# 4.0        529
# 3.0      13320
# 2.0     168362
# 1.0    1682347
# 0.0    1413803
# Name: count, dtype: int64

# %%
# Create dataframes of matches based on each feature set and the required number of matching features
matches_1 = features_1[features_1.sum(axis=1) >= 4]
matches_2 = features_2[features_2.sum(axis=1) >= 4]
matches_3 = features_3[features_3.sum(axis=1) >= 5]
matches_3
# Out:
#                                                                    last_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f             1
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13             1
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888             1
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67             1
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76             1
# ...                                                                         ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d             1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365             1
#                                  19a9297f2ebec21121290668ab89109e             1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d             1
#                                  d14aee7bce4016cd67755a6c356a9de9             1
#
#                                                                    first_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f              1
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13              1
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888              1
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67              1
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76              1
# ...                                                                          ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d              1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365              1
#                                  19a9297f2ebec21121290668ab89109e              1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d              1
#                                  d14aee7bce4016cd67755a6c356a9de9              1
#
#                                                                    first_initial  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f              1
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13              1
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888              1
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67              1
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76              1
# ...                                                                          ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d              1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365              1
#                                  19a9297f2ebec21121290668ab89109e              1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d              1
#                                  d14aee7bce4016cd67755a6c356a9de9              1
#
#                                                                    email_address_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f                    0
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13                    0
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888                    0
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67                    0
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76                    0
# ...                                                                                ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d                    1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365                    1
#                                  19a9297f2ebec21121290668ab89109e                    1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d                    1
#                                  d14aee7bce4016cd67755a6c356a9de9                    1
#
#                                                                    phone_number_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f                   1
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13                   1
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888                   1
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67                   1
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76                   1
# ...                                                                               ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d                   1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365                   1
#                                  19a9297f2ebec21121290668ab89109e                   1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d                   1
#                                  d14aee7bce4016cd67755a6c356a9de9                   1
#
#                                                                    title  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f      1
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13      1
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888      1
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67      1
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76      1
# ...                                                                  ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d      1
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365      1
#                                  19a9297f2ebec21121290668ab89109e      1
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d      1
#                                  d14aee7bce4016cd67755a6c356a9de9      1
#
#                                                                    company_name_clean
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 64db62708f598d0b7119d6f7e85506ef 266454807083e33b371c27f1b791419f                 0.0
# 6f88a3025b514be885813d27e44d0e73 e7f6d398e665d8878e0fa8bbf5c04b13                 0.0
# 1d6544eaafd5ee8bb49f9b273d2e71a6 f72d4dfbbc40a810c7f973aca6245888                 0.0
# 363f7e91fabf50c08d20432a139d567b 5ae3867f7fef687bc5fdcffa0fd25d67                 0.0
# 294284367f383ee2c4cee1c75807aab2 93e861690de01a286036483a37f66a76                 0.0
# ...                                                                               ...
# d121ed3c7f55c56ac8d0fa13a6eba6ee 9cb54cff1a5a6a72c16ceeeb9154894d                 1.0
# 672f1bae98aecbbd17469698283b976c bb11059c7febc5d65edb38fbca930365                 1.0
#                                  19a9297f2ebec21121290668ab89109e                 1.0
# 3972d538bf202fb438a0ac95e054367d 668b7c07fa1d8b51c2bf650530893a6d                 1.0
#                                  d14aee7bce4016cd67755a6c356a9de9                 1.0
#
# [2280 rows x 7 columns]

# %%
matches_1
# Out:
#                                                                    last_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6             1
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1             1
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f             1
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4             1
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1             1
# ...                                                                         ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440             1
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9             1
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9             1
#                                  7de3e72ed60fb434368e356b567182ff             1
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940             1
#
#                                                                    first_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6              1
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1              1
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f              1
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4              1
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1              1
# ...                                                                          ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440              1
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9              1
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9              1
#                                  7de3e72ed60fb434368e356b567182ff              1
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940              1
#
#                                                                    first_initial  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6              1
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1              1
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f              1
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4              1
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1              1
# ...                                                                          ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440              1
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9              1
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9              1
#                                  7de3e72ed60fb434368e356b567182ff              1
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940              1
#
#                                                                    email_address_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6                    0
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1                    0
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f                    0
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4                    0
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1                    0
# ...                                                                                ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440                    0
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9                    0
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9                    0
#                                  7de3e72ed60fb434368e356b567182ff                    0
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940                    0
#
#                                                                    phone_number_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6                   1
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1                   1
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f                   1
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4                   1
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1                   1
# ...                                                                               ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440                   1
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9                   1
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9                   1
#                                  7de3e72ed60fb434368e356b567182ff                   1
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940                   1
#
#                                                                    title  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6      1
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1      1
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f      1
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4      1
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1      0
# ...                                                                  ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440      1
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9      1
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9      1
#                                  7de3e72ed60fb434368e356b567182ff      1
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940      1
#
#                                                                    company_name_clean
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 4473b2e298a14b96e070bdd35931cdac 48be23db1ce587990b38ab791b5894b6                 0.0
# 5adbfe50986b2605164ec839d8b6b043 6a4838bc3c363453ec82617e275529a1                 0.0
# 6f81b478116852a0fd157d14ed2da76c cd8ad00270d1bb1f8f733f33ad004a2f                 0.0
# 46aafbdac1a8ae0bd731800725989d35 5235dc3fb1d8d60afa2a6ecb2e34e0b4                 0.0
# 245d74886b273b6cd8cfbdf110e5cc3b 6a4838bc3c363453ec82617e275529a1                 0.0
# ...                                                                               ...
# 01d1103f0f43a81d7dc999b95686d45d 420703d515811d3e06a8dc889298a440                 0.0
# 7de3e72ed60fb434368e356b567182ff f832cae619aed2b79a0d6e553be07be9                 0.0
# 50eb879a2dd2ee57917906fbffb2302f f832cae619aed2b79a0d6e553be07be9                 0.0
#                                  7de3e72ed60fb434368e356b567182ff                 0.0
# b3e0d6799aafd3a6d05d1ad61d0c7887 5b2fa7066f31d86b1cc9f29c4dc78940                 0.0
#
# [266 rows x 7 columns]

# %%
len(matches_1)
# Out:
# 266

# %%
len(matches_2)
# Out:
# 197

# %%
len(matches_3)
# Out:
# 2280

# %%
# Create and squash distinct sets of matched ids
comnbined_matches = pd.concat([matches_1, matches_2, matches_3]).sort_values(by = ['SOURCE_CONTACT_KEY_1', 'SOURCE_CONTACT_KEY_2'])
comnbined_matches
# Out:
#                                                                    last_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24             1
#                                  6cd6b6b9207ed30567a5b616331a4f24             1
#                                  a159962b278fad8e492b8e13b9922b5e             1
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4             1
#                                  0c1568d48c39346ad4573b7ab47ac4c4             1
# ...                                                                         ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321             1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786             1
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83             1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83             1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83             1
#
#                                                                    first_name_mp  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24              1
#                                  6cd6b6b9207ed30567a5b616331a4f24              1
#                                  a159962b278fad8e492b8e13b9922b5e              1
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4              1
#                                  0c1568d48c39346ad4573b7ab47ac4c4              1
# ...                                                                          ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321              1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786              1
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83              1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83              1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83              1
#
#                                                                    first_initial  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24              1
#                                  6cd6b6b9207ed30567a5b616331a4f24              1
#                                  a159962b278fad8e492b8e13b9922b5e              1
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4              1
#                                  0c1568d48c39346ad4573b7ab47ac4c4              1
# ...                                                                          ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321              1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786              1
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83              1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83              1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83              1
#
#                                                                    email_address_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24                    1
#                                  6cd6b6b9207ed30567a5b616331a4f24                    1
#                                  a159962b278fad8e492b8e13b9922b5e                    0
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4                    1
#                                  0c1568d48c39346ad4573b7ab47ac4c4                    1
# ...                                                                                ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321                    1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786                    0
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83                    1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                    1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                    1
#
#                                                                    phone_number_clean  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24                   0
#                                  6cd6b6b9207ed30567a5b616331a4f24                   0
#                                  a159962b278fad8e492b8e13b9922b5e                   0
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4                   1
#                                  0c1568d48c39346ad4573b7ab47ac4c4                   1
# ...                                                                               ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321                   1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786                   0
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83                   1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                   1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                   1
#
#                                                                    title  \
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24      1
#                                  6cd6b6b9207ed30567a5b616331a4f24      1
#                                  a159962b278fad8e492b8e13b9922b5e      1
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4      1
#                                  0c1568d48c39346ad4573b7ab47ac4c4      1
# ...                                                                  ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321      1
#                                  b1f633c4e0c47e1afadb98b2b0bc0786      1
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83      1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83      1
#                                  7ea9890c5e0efff6e5b8d4979ea6af83      1
#
#                                                                    company_name_clean
# SOURCE_CONTACT_KEY_1             SOURCE_CONTACT_KEY_2
# 002478c5c039af2573e0eb4ca4b2dd39 6cd6b6b9207ed30567a5b616331a4f24                 1.0
#                                  6cd6b6b9207ed30567a5b616331a4f24                 1.0
#                                  a159962b278fad8e492b8e13b9922b5e                 0.0
# 005fe2f9e3803d6d049e6cd2dae8583f 0c1568d48c39346ad4573b7ab47ac4c4                 1.0
#                                  0c1568d48c39346ad4573b7ab47ac4c4                 1.0
# ...                                                                               ...
# ffe87a08cf2ca9301af709e1dd50e1e3 58a0970f09ef35de0e6a632640816321                 1.0
#                                  b1f633c4e0c47e1afadb98b2b0bc0786                 0.0
# fff8c7014917f9571aaebcede32059be 7ea9890c5e0efff6e5b8d4979ea6af83                 1.0
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                 1.0
#                                  7ea9890c5e0efff6e5b8d4979ea6af83                 1.0
#
# [6946 rows x 7 columns]

# %%
key_maps = []
# Get all key maps
for idx, row in comnbined_matches.iterrows():
    keys = [idx[0], idx[1]]
    key_maps.append(keys)
key_maps.sort(key=lambda x: [x[0], x[1]])
len(key_maps)  # Too many, need to squash into distict matching group sets
# Out:
# 6946

# %%
i = 0
groups = []

for km in key_maps:
    in_group = False
    if i == 0:
        groups.append(km)
    else:
        for grp in groups:
            if km[0] in grp and km[1] not in grp:
                grp.append(km[1])
                in_group = True
            elif km[1] in grp and km[0] not in grp:
                grp.append(km[0])
                in_group = True
            elif km[1] in grp and km[0] in grp:
                in_group = True
    if not(in_group):
        groups.append(km)
    i = i + 1

len(groups)
# Out:
# 937

# %%
# Ensure each group is a unique, sorted set of keys
new_groups = []
for grp in groups:
    if len(grp) > 0:
        new_grp = sorted(list(set(grp)))
        new_groups.append(new_grp)

len(new_groups)
# Out:
# 937

# %%
new_df = pd.DataFrame({"matches": new_groups})
display(new_df)
# Out:
#                                                matches
# 0    [002478c5c039af2573e0eb4ca4b2dd39, 6cd6b6b9207...
# 1    [002478c5c039af2573e0eb4ca4b2dd39, 6cd6b6b9207...
# 2    [005fe2f9e3803d6d049e6cd2dae8583f, 0c1568d48c3...
# 3    [006422b9502c4dd2a60017dfe79fabfd, 15b889e6478...
# 4    [0074dc1ac23c22f2251e218059bab936, 51659802171...
# ..                                                 ...
# 932  [27b4b763a70cab13ad545de5a6d3e773, fd63a220601...
# 933  [bc3b01575b81c55e68c109637de86535, fe49585d5ab...
# 934  [1aa32777ba75e0690d387a518434d446, fe7eb6008b2...
# 935  [2140b08bccf1cae9b3beee4e6911bbed, ff171c5c13b...
# 936  [e3781b37efdbde1b44650e739b011be8, ffdfb0815dc...
#
# [937 rows x 1 columns]

# %%
new_df.to_csv('matches.csv')
